# %%
import pandas as pd

# %%
import os
import sys
from pathlib import Path

project_root = Path(__file__).parent.absolute()

ml_output_dir = os.path.join(project_root, "data", "outputs")

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from demo import WaterLevelDemo

# %% [markdown]
# # 1.   A頭首工　河川水位

# %%
demo_instance = WaterLevelDemo(ml_output_dir, "A頭首工")
demo_instance.load_data()
demo_instance.get_prediction("2023-05-22 06:00:00")
# Out:
# === 2023-05-22 06:00:00 の予測 ===
# 現在の水位: 2.58 m
# 予測の一時間後の水位: 2.59 m
# 処理時間: 1.9126 秒

# %% [markdown]
# # 2.   B頭首工　河川水位

# %%
demo_instance = WaterLevelDemo(ml_output_dir, "B頭首工")
demo_instance.load_data()
demo_instance.get_prediction("2023-05-22 06:00:00")
# Out:
# === 2023-05-22 06:00:00 の予測 ===
# 現在の水位: 1.93 m
# 予測の一時間後の水位: 1.93 m
# 処理時間: 1.5584 秒

# %% [markdown]
# # 3.   C頭首工　河川水位

# %%
demo_instance = WaterLevelDemo(ml_output_dir, "C頭首工")
demo_instance.load_data()
demo_instance.get_prediction("2023-05-22 06:00:00")
# Out:
# === 2023-05-22 06:00:00 の予測 ===
# 現在の水位: 2.86 m
# 予測の一時間後の水位: 2.86 m
# 処理時間: 1.2552 秒

# %% [markdown]
# # 4.   D頭首工　河川水位

# %%
demo_instance = WaterLevelDemo(ml_output_dir, "D頭首工")
demo_instance.load_data()
demo_instance.get_prediction("2023-05-22 06:00:00")
# Out:
# === 2023-05-22 06:00:00 の予測 ===
# 現在の水位: 2.14 m
# 予測の一時間後の水位: 2.14 m
# 処理時間: 1.2101 秒
